# %%
print("Hellow world")
# Out:
# Hellow world

# %%
print("Hellow world")
# Out:
# Hellow world

# %%
city="Noida"
print(city)
age=int(input())
num2=int(input())
type(age)
type(num2)
str="3.14"
floatstr=float(str)
print(f"My city is {city} and I am {age}.")
# Out:
# Noida
# My city is Noida and I am 67.

# %%
price="250"
quatily="3"
print(price)
# Out:
# 250

# %%
city=str(input("Enyer the city name:"))
print(f"The city name is {city}.")

# for to know lenght use the function len()
# Out:
# The city name is Jaunpur.

# %%
pi="3.14"
pi=float(pi)
si=pi*2
print(f"p*2={si}")
# Out:
# p*2=6.28

# %%
name="Anand"
print(name[0])
print(name[3])
# Out:
# A
# n

# %%
name="Anand"
print(name[0:4])
print(name[3:4])
# Out:
# Anan
# n

# %%
messy=" Anand Dueby "
print(messy.upper())
print(messy.lower())
print(f"'{messy.strip()}'")
# Out:
#  ANAND DUEBY
#  anand dueby
# 'Anand Dueby'

# %%
sentence="python is easy to learn"
words=sentence.split()
print(words)
# Out:
# ['python', 'is', 'easy', 'to', 'learn']

# %%
first="Data"
second=" visualisation"
print(first + second)
# Out:
# Data visualisation

# %%
name="Anand Dueby"
print(len(name))
print(name[:3])

greet=" hello world "
print(greet.strip())
print(greet.upper())
print("one two three four five".split(" ",2))
# Out:
# 11
# Ana
# hello world
#  HELLO WORLD
# ['one', 'two', 'three four five']

# %%
marks=[40,20,70,80,10]
print(marks[0])
marks[0]=100
print(marks)
marks.append(50)
print(marks)
marks.remove(70)
print(marks)
marks.sort()
print(marks)
marks.sort(reverse=True)
print(marks)
# Out:
# 40
# [100, 20, 70, 80, 10]
# [100, 20, 70, 80, 10, 50]
# [100, 20, 80, 10, 50]
# [10, 20, 50, 80, 100]
# [100, 80, 50, 20, 10]

# %%
number=[78,85,62,90,74]
print("count :", len(number))
# Out:
# count : 5

# %%
temp=[70,60,50,10]
print("maximum temprature :", max(temp))
print("minimun temprature:", min(temp))
# Out:
# maximum temprature : 70
# minimun temprature: 10

# %%
x=
