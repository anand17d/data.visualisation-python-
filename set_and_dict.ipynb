# %%
language={"python","java","python","C++","java"}
print(language)
# Out:
# {'C++', 'java', 'python'}

# %%
student={
    "name": "Anand",
    
}

# %%
books ={ "title":"python programming","author":"john Doe","pages":500,"years": 2021}
print(books)
# Out:
# {'title': 'python programming', 'author': 'john Doe', 'pages': 500, 'years': 2021}

# %%
students={
    "student1":{"name":"Alice","age":20,"course":"Python"},
    "student2":{"name":"Anand","age":19,"course":"Data Science"}
}
print(students["student1"])

print(students["student1"]["name"])
print(students["student2"]["course"])

# Loop through all students
for student_id,details in students.items():
    print(student_id,":",details["name"],"-",details["course"])
# Out:
# {'name': 'Alice', 'age': 20, 'course': 'Python'}
# Alice
# Data Science
# student1 : Alice - Python
# student2 : Anand - Data Science

# %%
print(students.get("course"))
print(students.get("city"))
# Out:
# None
# None
