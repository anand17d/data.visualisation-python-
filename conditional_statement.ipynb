# %%
score = 82
if score >= 80: 
    print("A")
# Out:
# A

# %%
marks =[34,45,67,87,]
for mark in marks:
    if mark >= 80:
        print("A")
    elif mark >= 70:
        print("B")
    elif mark >= 60:
        print("C")
    elif mark >= 50:
        print("D")
    else:
        print
# Out:
# F
# F
# C
# A
